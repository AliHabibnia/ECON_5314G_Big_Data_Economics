# %% [markdown]
# ## <center><font color=navy>Big Data Economics</font></center>
# ### <center>Linear Fator Models</center>
# #### <center>Ali Habibnia</center>
#
# <center> Assistant Professor, Department of Economics, </center>
# <center> and Division of Computational Modeling & Data Analytics at Virginia Tech</center>
# <center> habibnia@vt.edu </center>

# %% [markdown]
# ### Readings:
#
# 1. [Topics in Mathematics with Applications in Finance,](https://ocw.mit.edu/courses/mathematics/18-s096-topics-in-mathematics-with-applications-in-finance-fall-2013/lecture-notes/MIT18_S096F13_lecnote15.pdf)
#
# 2. Jushan Bai, and Serena Ng, [RECENT DEVELOPMENTS IN LARGE DIMENSIONAL FACTORANALYSIS](http://www.columbia.edu/~sn2294/papers/survey.pdf)
#
# 3. Matteo Barigozzi, [DYNAMIC FACTOR MODELS](http://www.barigozzi.eu/MB_DF_lecture_notes.pdf)

# %% [markdown]
# ### Factor modeling/analysis
#
# > In the Factor Analysis technique, variables are grouped by their correlations, i.e., all variables in a particular group will have a high correlation among themselves, but a low correlation with variables of other group(s). Here, each group is known as a factor. These factors are small in number as compared to the original dimensions of the data. However, these factors are difficult to observe. With factor models, we want to capture the main structure in the data with fewer and more informative features. Dimension Reduction (DR) is often the first step in the analysis, followed by, e.g., forecasting, visualization, clustering, regression, classification.
#
# - A linear (statistical) Factor Model is a decomposition of the target/dependent varibale as a linear combination of factors plus residuals, as follows
#
# <img src="images/LFM0.png"  width="350">
#
# where $\Phi_i$ and $F_t$ are column vectors of dimension $k$.
#
# <br>
# Certainly one needs to estimate $\Phi_i$ and $F_t$:  there are techniques (e.g.PCA, Kalman filtering, MLE, etc...)

# %% [markdown]
# <img src="images/LFM1.png"  width="700">

# %% [markdown]
# ### Example: Factor Models for Asset Returns

# %% [markdown]
# #### Three Types of Factor Models
# 1. Macroeconomic factor model
#     - Factors are observable economic and financial time series
#
#     <img src="images/macro.png"  width="500">
#     <img src="images/capm.png"  width="500">

# %% [markdown]
# 2. Fundamental factor model
#     - Factors are created from observerable asset characteristics
#
#         <img src="images/fundamental.png"  width="500">
#         <img src="images/fama.png"  width="500">
#         <img src="images/fama2.png"  width="500">

# %% [markdown]
# 3. Statistical factor model (Big Data)
#     - Factors are unobservable and extracted from data (i.e. asset returns)
#
#         <img src="images/FM_Fin0.png"  width="600">
#         <img src="images/assumptions.png"  width="600">
#         <img src="images/notation.png"  width="600">
#         <img src="images/cross-section.png"  width="600">
#         <img src="images/timeseries.png"  width="600">
#         <img src="images/panel.png"  width="600">

# %% [markdown]
# <img src="images/sfm.png"  width="600">
# <img src="images/sfm1.png"  width="600">
#
# <img src="images/sfm2.png"  width="600">
#
# <img src="images/sfm3.png"  width="600">
#
# <img src="images/sfm5.png"  width="600">
#
# <img src="images/sfm6.png"  width="600">

# %% [markdown]
# ### Factor Analysis in Python
#
# #### sklearn.decomposition.FactorAnalysis
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FactorAnalysis.html

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('9PL_NOJWKZs')

# %% [markdown]
# #### Statsmodels Example for Dynamic factors and coincident indices
#
# https://www.statsmodels.org/dev/examples/
#
# https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_dfm_coincident.html
